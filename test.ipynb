# %%
from youtube.search_engine import VideosSearch
import json

# %%
videosSearch = VideosSearch(
    query='spin9',
    language='th',
    limit=999
)
print(json.dumps(videosSearch.result(), indent=4))
# Out:
# {
#     "result": [
#         {
#             "type": "video",
#             "id": "kBUGsC0w_Tk",
#             "title": "[spin9] \u0e23\u0e35\u0e27\u0e34\u0e27 Mercedes-Benz E 200 Coup\u00e9 / Cabriolet \u0e42\u0e09\u0e21\u0e43\u0e2b\u0e21\u0e48 \u2013 \u0e40\u0e21\u0e37\u0e48\u0e2d\u0e2d\u0e32\u0e23\u0e21\u0e13\u0e4c\u0e0a\u0e19\u0e30\u0e17\u0e38\u0e01\u0e40\u0e2b\u0e15\u0e38\u0e1c\u0e25",
#             "publishedTime": "1 week ago",
#             "duration": "20:53",
#             "viewCount": {
#                 "text": "73,159 views",
#                 "short": "73K views"
#             },
#             "thumbnails": [
#                 {
#                     "url": "https://i.ytimg.com/vi/kBUGsC0w_Tk/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLAmQK_Cz5N6BK6VRAErJ7_xyL3zRA",
#                     "width": 360,
#                     "height": 202
#                 },
#                 {
# ...
